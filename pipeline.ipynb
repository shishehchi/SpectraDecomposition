# %%
import numpy as np
import tensorflow

# %%
from helpers.Classifier import Model_class
from helper import PLOT_Single_Decompse_NII
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-c2a364c9d774> in <module>
# ----> 1 from helpers.Classifier import Model_class
#       2 from helper import PLOT_Single_Decompse_NII
#
# ~/Documents/HT_Project/paper3/latestCode/helpers/Classifier.py in <module>
#       3 import astropy.units as u
#       4 import tensorflow
# ----> 5 from tensorflow.keras.layers import Input,concatenate, Dense, UpSampling1D,Conv1D,Flatten,Reshape,Dropout,LeakyReLU
#       6 from tensorflow.keras.models import Model
#       7 from tensorflow.keras import backend as K
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/keras/__init__.py in <module>
#      12 import sys as _sys
#      13
# ---> 14 from . import activations
#      15 from . import applications
#      16 from . import backend
#
# ...

# %%
from tensorflow.keras.layers import Input,concatenate, Dense, UpSampling1D,Conv1D,Flatten,Reshape,Dropout,LeakyReLU
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-c01c447936a2> in <module>
# ----> 1 from tensorflow.keras.layers import Input,concatenate, Dense, UpSampling1D,Conv1D,Flatten,Reshape,Dropout,LeakyReLU
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/keras/__init__.py in <module>
#      12 import sys as _sys
#      13
# ---> 14 from . import activations
#      15 from . import applications
#      16 from . import backend
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/keras/activations/__init__.py in <module>
#       8 import sys as _sys
#       9
# ---> 10 from tensorflow.python.keras.activations import deserialize
#      11 from tensorflow.python.keras.activations import elu
#      12 from tensorflow.python.keras.activations import exponential
#
# ModuleNotFoundError: No module named 'tensorflow.python.keras.activations'

# %%
model = Model_class()

# %%
tensorflow.keras.utils.plot_model(model, "model_with_shape_info.png", show_shapes=True)

# %%
X = np.load("data/SpecInput.npy")
mass = np.load("data/SpecWeights.npy")
wl = np.load('data/wl_2Ao2.npy')

# %%
# normalizing input specs

idx = np.where((wl>4000)&(wl<=7000))[0]
Xn = []

for k1 in range(len(X)):
    med= np.median(X[k1][idx])
    std= np.std(X[k1][idx])
    Xn.append((X[k1]-med)/std/mass[k1])

# %%
PLOT_Single_Decompse_NII(Xn, n_spec=2, Fig_save=1, Fig_name='Decompose-BPT-02.png')
