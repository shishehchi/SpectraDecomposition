# %%
import numpy as np
import tensorflow
# Out:
# 2023-12-20 20:00:48.791659: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
from helpers.Classifier import Model_class
from helpers.helper import PLOT_Single_Decompse_NII
# Out:
# 2023-12-20 20:00:52.158549: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-20 20:00:52.174409: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-20 20:00:52.176577: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-20 20:00:52.179210: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# ...

# %%
model = Model_class()

# %%
tensorflow.keras.utils.plot_model(model, "model_with_shape_info.png", show_shapes=True)

# %%
X = np.load("data/Spect_20SDSS.npy")
mass = np.load("data/Mass_20SDSS.npy")
wl = np.load('data/wl_2Ao2.npy')

# %%
# normalizing input specs

idx = np.where((wl>4000)&(wl<=7000))[0]
Xn = []

for k1 in range(len(X)):
    med= np.median(X[k1][idx])
    std= np.std(X[k1][idx])
    Xn.append((X[k1]-med)/std/mass[k1])

# %%
from matplotlib import pyplot as plt

# %%
PLOT_Single_Decompse_NII(model, Xn, n_spec=6, Fig_save=1, Fig_name='Decompose-BPT-02.png')
# Out:
# ...
# 1/1 [==============================] - 0s 34ms/step
# 6
